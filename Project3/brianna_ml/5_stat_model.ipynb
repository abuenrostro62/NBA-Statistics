# %%
import pandas as pd
from sklearn.ensemble import RandomForestRegressor
from sklearn.model_selection import train_test_split

# %%
#Import Data from the first 5 years of MJs professional career
mj1_df = pd.read_csv('./Data/first_year.csv')
mj1_df.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  ...  \
# 0   1  1  1984-10-26  21-252  CHI        NaN  WSB    W (+16)   1  40:00  ...
# 1   2  2  1984-10-27  21-253  CHI          @  MIL     L (-2)   1  34:00  ...
# 2   3  3  1984-10-29  21-255  CHI        NaN  MIL     W (+6)   1  34:00  ...
# 3   4  4  1984-10-30  21-256  CHI          @  KCK     W (+5)   1  36:00  ...
# 4   5  5  1984-11-01  21-258  CHI          @  DEN    L (-16)   1  33:00  ...
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc
# 0    1    5    6    7    2    4    5   2   16  12.5
# 1    3    2    5    5    2    1    3   4   21  19.4
# 2    2    2    4    5    6    2    3   4   37  32.9
# 3    2    2    4    5    3    1    6   5   25  14.7
# 4    3    2    5    5    1    1    2   4   17  13.2
#
# [5 rows x 29 columns]

# %%
mj2_df = pd.read_csv('./Data/second_year.csv')
mj2_df.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  ...  \
# 0   1  1  1985-10-25  22-250  CHI        NaN  CLE     W (+1)   1  39:00  ...
# 1   2  2  1985-10-26  22-251  CHI        NaN  DET     W (+3)   1  41:00  ...
# 2   3  3  1985-10-29  22-254  CHI          @  GSW     W (+6)   1  18:00  ...
# 3   4  4  1986-03-15  23-026  CHI        NaN  MIL     L (-9)   0  13:00  ...
# 4   5  5  1986-03-17  23-028  CHI          @  ATL    L (-10)   0  14:00  ...
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc
# 0    3    3    6    3    3    0    3   5   29  18.7
# 1    2    5    7    6    2    3    6   5   33  22.6
# 2    0    2    2    2    0    0    1   1   12   8.0
# 3    0    1    1    2    1    0    1   2   12   8.4
# 4    3    1    4    1    7    1    1   0   17  16.8
#
# [5 rows x 29 columns]

# %%
mj3_df = pd.read_csv('./Data/third_year.csv')
mj3_df.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  ...  \
# 0   1  1  1986-11-01  23-257  CHI          @  NYK     W (+5)   1  41:00  ...
# 1   2  2  1986-11-02  23-258  CHI          @  CLE     W (+5)   1  39:00  ...
# 2   3  3  1986-11-04  23-260  CHI        NaN  SAS     W (+7)   1  44:00  ...
# 3   4  4  1986-11-07  23-263  CHI          @  DET     L (-6)   1  42:00  ...
# 4   5  5  1986-11-08  23-264  CHI        NaN  PHO     W (+5)   1  39:00  ...
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc
# 0    2    4    6    3    4    3    6   2   50  37.5
# 1    6    2    8    2    0    4    3   3   41  29.3
# 2    3    5    8    5    4    2    6   2   34  20.8
# 3    0    0    0    5    1    1    3   4   33  18.2
# 4    3    3    6    3    5    0    3   2   39  33.2
#
# [5 rows x 29 columns]

# %%
mj4_df = pd.read_csv('./Data/fourth_year.csv')
mj4_df.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  ...  \
# 0   1  1  1987-11-07  24-263  CHI        NaN  PHI    W (+10)   1  38:00  ...
# 1   2  2  1987-11-10  24-266  CHI          @  ATL    W (+10)   1  42:00  ...
# 2   3  3  1987-11-11  24-267  CHI          @  NJN     W (+9)   1  40:00  ...
# 3   4  4  1987-11-13  24-269  CHI        NaN  NJN    W (+18)   1  35:00  ...
# 4   5  5  1987-11-14  24-270  CHI        NaN  IND     L (-1)   1  40:00  ...
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc
# 0    2    3    5    3    6    4    2   3   36  32.9
# 1    0    6    6    7    1    1    3   3   29  20.3
# 2    1    2    3    4    2    0    5   4   31  19.7
# 3    3    4    7    5    6    1    3   1   36  36.4
# 4    3    2    5    5    4    1    3   3   37  28.2
#
# [5 rows x 29 columns]

# %%
mj5_df = pd.read_csv('./Data/fifth_year.csv')
mj5_df.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  ...  \
# 0   1  1  1988-11-04  25-261  CHI        NaN  DET    L (-13)   1  43:00  ...
# 1   2  2  1988-11-05  25-262  CHI          @  WSB    W (+13)   1  39:00  ...
# 2   3  3  1988-11-08  25-265  CHI          @  NYK     L (-9)   1  39:00  ...
# 3   4  4  1988-11-09  25-266  CHI          @  BOS     W (+6)   1  42:00  ...
# 4   5  5  1988-11-11  25-268  CHI        NaN  NJN    W (+12)   1  41:00  ...
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc
# 0    1    4    5    7    5    2    2   5   28  26.3
# 1    0    2    2    7    3    0    5   4   29  19.4
# 2    2    1    3    9    2    0    4   5   31  25.5
# 3    0    3    3    2    9    2    2   4   52  44.4
# 4    1    5    6    3    3    4    6   2   36  26.9
#
# [5 rows x 29 columns]

# %%
final_df = pd.concat([mj1_df, mj2_df, mj3_df, mj4_df, mj5_df])

# %%
#Connect them all together and see what adjustments need to be made
final_df.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  ...  \
# 0   1  1  1984-10-26  21-252  CHI        NaN  WSB    W (+16)   1  40:00  ...
# 1   2  2  1984-10-27  21-253  CHI          @  MIL     L (-2)   1  34:00  ...
# 2   3  3  1984-10-29  21-255  CHI        NaN  MIL     W (+6)   1  34:00  ...
# 3   4  4  1984-10-30  21-256  CHI          @  KCK     W (+5)   1  36:00  ...
# 4   5  5  1984-11-01  21-258  CHI          @  DEN    L (-16)   1  33:00  ...
#
#    ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc
# 0    1    5    6    7    2    4    5   2   16  12.5
# 1    3    2    5    5    2    1    3   4   21  19.4
# 2    2    2    4    5    6    2    3   4   37  32.9
# 3    2    2    4    5    3    1    6   5   25  14.7
# 4    3    2    5    5    1    1    2   4   17  13.2
#
# [5 rows x 29 columns]

# %%
print('The shape of our data is:', final_df.shape)
# Out:
# The shape of our data is: (345, 29)

# %%
final_df.describe()
# Out:
#                Rk           G          GS          FG         FGA         FG%  \
# count  345.000000  345.000000  345.000000  345.000000  345.000000  345.000000
# mean    39.713043   39.713043    0.968116   11.942029   23.260870    0.515641
# std     24.108319   24.108319    0.175947    3.794442    6.097207    0.108754
# min      1.000000    1.000000    0.000000    3.000000    7.000000    0.176000
# 25%     18.000000   18.000000    1.000000    9.000000   19.000000    0.444000
# 50%     39.000000   39.000000    1.000000   12.000000   23.000000    0.516000
# 75%     61.000000   61.000000    1.000000   14.000000   27.000000    0.588000
# max     82.000000   82.000000    1.000000   24.000000   43.000000    0.828000
#
#                3P         3PA         3P%          FT  ...         ORB  \
# count  345.000000  345.000000  174.000000  345.000000  ...  345.000000
# mean     0.168116    0.831884    0.173080    8.594203  ...    1.866667
# ...

# %%
#Adjust date and add new columns
final_df['Date'] = pd.to_datetime(final_df['Date'], errors='coerce')

final_df['Year'] = final_df['Date'].dt.year
final_df['Month'] = final_df['Date'].dt.month
final_df['Day'] = final_df['Date'].dt.day

# %%
for z in final_df.columns:
    print(z)
# Out:
# Rk
# G
# Date
# Age
# Tm
# Unnamed: 5
# Opp
# Unnamed: 7
# GS
# MP
# FG
# FGA
# FG%
# 3P
# 3PA
# 3P%
# FT
# FTA
# FT%
# ORB
# DRB
# TRB
# AST
# STL
# BLK
# TOV
# PF
# PTS
# GmSc
# Year
# Month
# Day

# %%
final_df.head()
# Out:
#    Rk  G       Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  ...  \
# 0   1  1 1984-10-26  21-252  CHI        NaN  WSB    W (+16)   1  40:00  ...
# 1   2  2 1984-10-27  21-253  CHI          @  MIL     L (-2)   1  34:00  ...
# 2   3  3 1984-10-29  21-255  CHI        NaN  MIL     W (+6)   1  34:00  ...
# 3   4  4 1984-10-30  21-256  CHI          @  KCK     W (+5)   1  36:00  ...
# 4   5  5 1984-11-01  21-258  CHI          @  DEN    L (-16)   1  33:00  ...
#
#    AST  STL  BLK  TOV  PF  PTS  GmSc  Year  Month  Day
# 0    7    2    4    5   2   16  12.5  1984     10   26
# 1    5    2    1    3   4   21  19.4  1984     10   27
# 2    5    6    2    3   4   37  32.9  1984     10   29
# 3    5    3    1    6   5   25  14.7  1984     10   30
# 4    5    1    1    2   4   17  13.2  1984     11    1
#
# [5 rows x 32 columns]

# %%
#Drop columns that are irrelevant to analysis
#Dropping date as it will interrupt one hot encoding later on
new_df = final_df.drop(columns=['Rk','G', 'Date','Age','Tm','Unnamed: 5','Opp','Unnamed: 7','GS','FG%','3P%','FT%','GmSc'])

# %%
mj_df = new_df.replace(':00','', regex=True)

# %%
mj_df.head()
# Out:
#    MP  FG  FGA  3P  3PA  FT  FTA  ORB  DRB  TRB  AST  STL  BLK  TOV  PF  PTS  \
# 0  40   5   16   0    0   6    7    1    5    6    7    2    4    5   2   16
# 1  34   8   13   0    0   5    5    3    2    5    5    2    1    3   4   21
# 2  34  13   24   0    0  11   13    2    2    4    5    6    2    3   4   37
# 3  36   8   21   0    0   9    9    2    2    4    5    3    1    6   5   25
# 4  33   7   15   0    0   3    4    3    2    5    5    1    1    2   4   17
#
#    Year  Month  Day
# 0  1984     10   26
# 1  1984     10   27
# 2  1984     10   29
# 3  1984     10   30
# 4  1984     11    1

# %%
# Use datetime for dealing with dates
import datetime

# Get years, months, and days
years = mj_df['Year']
months = mj_df['Month']
days = mj_df['Day']

# List and then convert to datetime object 
dates = [str(int(year)) + '-' + str(int(month)) + '-' + str(int(day)) for year, month, day in zip(years, months, days)]
dates = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in dates]

# %%
# Import matplotlib for plotting and use magic command for Jupyter Notebooks
import matplotlib.pyplot as plt

# %matplotlib inline

# Set the style
plt.style.use('fivethirtyeight')

# %%
# Set up the plotting layout
fig, ((ax1), (ax2), (ax3), (ax4), (ax5)) = plt.subplots(nrows=5, ncols=1, figsize = (30,30))
fig.autofmt_xdate(rotation = 45)

# Field Goals 
ax1.plot(dates, mj_df['FG'])
ax1.set_xlabel('Date'); ax1.set_ylabel('Made'); ax1.set_title('Field Goals')

# Free Throws
ax2.plot(dates, mj_df['FT'])
ax2.set_xlabel('Date'); ax2.set_ylabel('Made'); ax2.set_title('Free Throw')

# Offensive Rebounds
ax3.plot(dates, mj_df['ORB'])
ax3.set_xlabel('Date'); ax3.set_ylabel('Made'); ax3.set_title('Offensive Rebounds')

# Turnovers
ax4.plot(dates, mj_df['TOV'])
ax4.set_xlabel('Date'); ax4.set_ylabel('Made'); ax4.set_title('Turnovers')

# Points
ax5.plot(dates, mj_df['PF'])
ax5.set_xlabel('Date'); ax5.set_ylabel('Made'); ax5.set_title('Personal Fouls')

plt.show
# Out:
# /Users/strawberrymeow/opt/anaconda3/lib/python3.7/site-packages/pandas/plotting/_matplotlib/converter.py:103: FutureWarning: Using an implicitly registered datetime converter for a matplotlib plotting method. The converter was registered by pandas on import. Future versions of pandas will require you to explicitly register matplotlib converters.
#
# To register the converters:
# 	>>> from pandas.plotting import register_matplotlib_converters
# 	>>> register_matplotlib_converters()
#   warnings.warn(msg, FutureWarning)
# <function matplotlib.pyplot.show(*args, **kw)>

# %%
# Use numpy to convert to arrays
import numpy as np

# Labels are the values we want to predict
labels = np.array(mj_df['PTS'])

# Remove the labels from the features
# axis 1 refers to the columns
mj_df = mj_df.drop('PTS', axis = 1)

# Saving feature names for later use
df_list = list(mj_df.columns)

# Convert to numpy array
mj_df = np.array(mj_df)

# %%
# Using Skicit-learn to split data into training and testing sets
from sklearn.model_selection import train_test_split

# Split the data into training and testing sets
train_features, test_features, train_labels, test_labels = train_test_split(mj_df, labels, test_size = 0.25,
                                                                                                               random_state = 42)

# %%
print('Training Features Shape:', train_features.shape)
print('Training Labels Shape:', train_labels.shape)
print('Testing Features Shape:', test_features.shape)
print('Testing Labels Shape:', test_labels.shape)
# Out:
# Training Features Shape: (258, 18)
# Training Labels Shape: (258,)
# Testing Features Shape: (87, 18)
# Testing Labels Shape: (87,)

# %%
# Import the model we are using
from sklearn.ensemble import RandomForestRegressor

# Instantiate model 
rf = RandomForestRegressor(n_estimators= 1000, random_state=42)

# Train the model on training data
rf.fit(train_features, train_labels);

# %%
# Use the forest's predict method on the test data
predictions = rf.predict(test_features)

# Calculate the absolute errors
errors = abs(predictions - test_labels)

# Print out the mean absolute error (mae)
print('Mean Absolute Error:', round(np.mean(errors), 2), 'points.')
# Out:
# Mean Absolute Error: 1.07 points.

# %%
# Potentially not important as MAPE does not apply to basketball
# Calculate mean absolute percentage error (MAPE)
mape = 100 * (errors / test_labels)

# Calculate and display accuracy
accuracy = 100 - np.mean(mape)
print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Accuracy: 96.51 %.

# %%
rf_new = RandomForestRegressor(n_estimators = 100, criterion = 'mse', max_depth = None, 
                               min_samples_split = 2, min_samples_leaf = 1)

# %%
# Get numerical feature importances
importances = list(rf.feature_importances_)

# List of tuples with variable and importance
feature_importances = [(feature, round(importance, 2)) for feature, importance in zip(df_list, importances)]

# Sort the feature importances by most important first
feature_importances = sorted(feature_importances, key = lambda x: x[1], reverse = True)

# Print out the feature and importances 
[print('Variable: {:20} Importance: {}'.format(*pair)) for pair in feature_importances];
# Out:
# Variable: FG                   Importance: 0.83
# Variable: FT                   Importance: 0.11
# Variable: FTA                  Importance: 0.04
# Variable: MP                   Importance: 0.0
# Variable: FGA                  Importance: 0.0
# Variable: 3P                   Importance: 0.0
# Variable: 3PA                  Importance: 0.0
# Variable: ORB                  Importance: 0.0
# Variable: DRB                  Importance: 0.0
# Variable: TRB                  Importance: 0.0
# Variable: AST                  Importance: 0.0
# Variable: STL                  Importance: 0.0
# Variable: BLK                  Importance: 0.0
# Variable: TOV                  Importance: 0.0
# Variable: PF                   Importance: 0.0
# Variable: Year                 Importance: 0.0
# Variable: Month                Importance: 0.0
# Variable: Day                  Importance: 0.0

# %%
# New random forest with only the two most important variables
rf_most_important = RandomForestRegressor(n_estimators= 1000, random_state=42)

# Extract the two most important features
important_indices = [df_list.index('FG'), df_list.index('FT')]
train_important = train_features[:, important_indices]
test_important = test_features[:, important_indices]

# Train the random forest
rf_most_important.fit(train_important, train_labels)

# Make predictions and determine the error
predictions = rf_most_important.predict(test_important)

errors = abs(predictions - test_labels)

# Display the performance metrics
print('Mean Absolute Error:', round(np.mean(errors), 2), 'points.')

mape = np.mean(100 * (errors / test_labels))
accuracy = 100 - mape

print('Accuracy:', round(accuracy, 2), '%.')
# Out:
# Mean Absolute Error: 0.62 degrees.
# Accuracy: 97.91 %.

# %%
# list of x locations for plotting
x_values = list(range(len(importances)))

# Make a bar chart
plt.bar(x_values, importances, orientation = 'vertical')

# Tick labels for x axis
plt.xticks(x_values, df_list, rotation='vertical')

# Axis labels and title
plt.ylabel('Importance'); plt.xlabel('Variable'); plt.title('Variable Importances');

# %%
# Dates of training values
months = mj_df[:, df_list.index('Month')]
days = mj_df[:, df_list.index('Day')]
years = mj_df[:, df_list.index('Year')]

# List and then convert to datetime object
dates = [str(int(year)) + '-' + str(int(month)) + '-' + str(int(day)) for year, month, day in zip(years, months, days)]
dates = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in dates]

# Dataframe with true values and dates
true_data = pd.DataFrame(data = {'date': dates, 'actual': labels})

# Dates of predictions
months = test_features[:, df_list.index('Month')]
days = test_features[:, df_list.index('Day')]
years = test_features[:, df_list.index('Year')]

# Column of dates
test_dates = [str(int(year)) + '-' + str(int(month)) + '-' + str(int(day)) for year, month, day in zip(years, months, days)]

# Convert to datetime objects
test_dates = [datetime.datetime.strptime(date, '%Y-%m-%d') for date in test_dates]

# Dataframe with predictions and dates
predictions_data = pd.DataFrame(data = {'date': test_dates, 'prediction': predictions})

# %%
# Plot the actual values
plt.plot(true_data['date'], true_data['actual'], 'b-', label = 'actual')

# Plot the predicted values
plt.plot(predictions_data['date'], predictions_data['prediction'], 'ro', label = 'prediction')
plt.xticks(rotation = '60'); 
plt.legend()

# Graph labels
plt.xlabel('Date'); plt.ylabel('Points'); plt.title('Actual and Predicted Values');
