# %%
import pandas as pd

# %%
#Import Data from MJs professional career
mj1_df = pd.read_csv('./Data/first_year.csv')
mj2_df = pd.read_csv('./Data/second_year.csv')
mj3_df = pd.read_csv('./Data/third_year.csv')
mj4_df = pd.read_csv('./Data/fourth_year.csv')
mj5_df = pd.read_csv('./Data/fifth_year.csv')
mj6_df = pd.read_csv('./Data/89_90.csv')
mj7_df = pd.read_csv('./Data/90_91.csv')
mj8_df = pd.read_csv('./Data/91_92.csv')
mj9_df = pd.read_csv('./Data/92_93.csv')
mj10_df = pd.read_csv('./Data/94_95.csv')
mj11_df = pd.read_csv('./Data/95_96.csv')
mj12_df = pd.read_csv('./Data/96_97.csv')
mj13_df = pd.read_csv('./Data/97_98.csv')
mj14_df = pd.read_csv('./Data/01_02.csv')
mj15_df = pd.read_csv('./Data/02_03.csv')

# %%
mj14_df.head()
# Out:
#    Rk  G        Date     Age   Tm Unnamed: 5  Opp Unnamed: 7  GS     MP  ...  \
# 0   1  1  2001-10-30  38-255  WAS          @  NYK     L (-2)   1  36:42  ...
# 1   2  2  2001-11-01  38-257  WAS          @  ATL    W (+10)   1  40:23  ...
# 2   3  3  2001-11-03  38-259  WAS        NaN  PHI    W (+14)   1  38:06  ...
# 3   4  4  2001-11-04  38-260  WAS          @  DET    L (-22)   1  22:29  ...
# 4   5  5  2001-11-07  38-263  WAS          @  BOS     L (-9)   1  40:34  ...
#
#    DRB  TRB  AST  STL  BLK  TOV  PF  PTS  GmSc  +/-
# 0    2    5    6    4    0    3   3   19  13.4   -9
# 1    6    6    6    2    0    1   2   31  21.0    6
# 2    4    6    9    2    1    2   1   20  16.1   14
# 3    8    8    2    1    0    1   1   19  13.0  -24
# 4    6    8    2    2    0    5   2   32  18.6   -8
#
# [5 rows x 30 columns]

# %%
final_df = pd.concat([mj1_df, mj2_df, mj3_df, mj4_df, mj5_df, mj6_df, mj7_df, mj8_df, mj9_df, mj10_df, mj11_df, mj12_df, mj13_df, mj14_df, mj15_df])
# Out:
# /Users/strawberrymeow/opt/anaconda3/lib/python3.7/site-packages/ipykernel_launcher.py:1: FutureWarning: Sorting because non-concatenation axis is not aligned. A future version
# of pandas will change to not sort by default.
#
# To accept the future behavior, pass 'sort=False'.
#
# To retain the current behavior and silence the warning, pass 'sort=True'.
#
#   """Entry point for launching an IPython kernel.

# %%
final_df.head()
# Out:
#    +/-  3P  3P%  3PA  AST     Age  BLK  DRB        Date  FG  ...  Opp  PF  \
# 0  NaN   0  NaN    0    7  21-252    4    5  1984-10-26   5  ...  WSB   2
# 1  NaN   0  NaN    0    5  21-253    1    2  1984-10-27   8  ...  MIL   4
# 2  NaN   0  NaN    0    5  21-255    2    2  1984-10-29  13  ...  MIL   4
# 3  NaN   0  NaN    0    5  21-256    1    2  1984-10-30   8  ...  KCK   5
# 4  NaN   0  NaN    0    5  21-258    1    2  1984-11-01   7  ...  DEN   4
#
#    PTS  Rk  STL  TOV  TRB   Tm Unnamed: 5  Unnamed: 7
# 0   16   1    2    5    6  CHI        NaN     W (+16)
# 1   21   2    2    3    5  CHI          @      L (-2)
# 2   37   3    6    3    4  CHI        NaN      W (+6)
# 3   25   4    3    6    4  CHI          @      W (+5)
# 4   17   5    1    2    5  CHI          @     L (-16)
#
# [5 rows x 30 columns]

# %%
print('The shape of our data is:', final_df.shape)
# Out:
# The shape of our data is: (1072, 30)

# %%
final_df.describe()
# Out:
#               +/-           3P         3P%          3PA          AST  \
# count  142.000000  1072.000000  742.000000  1072.000000  1072.000000
# mean     0.140845     0.541978    0.272920     1.658582     5.254664
# std     12.369943     0.970196    0.341417     1.752960     2.722709
# min    -35.000000     0.000000    0.000000     0.000000     0.000000
# 25%     -8.000000     0.000000    0.000000     0.000000     3.000000
# 50%      1.000000     0.000000    0.000000     1.000000     5.000000
# 75%      9.000000     1.000000    0.500000     3.000000     7.000000
# max     32.000000     7.000000    1.000000    12.000000    17.000000
#
#                BLK          DRB           FG          FG%          FGA  ...  \
# count  1072.000000  1072.000000  1072.000000  1072.000000  1072.000000  ...
# mean      0.833022     4.667910    11.373134     0.495741    22.888993  ...
# std       1.011194     2.569624     3.825897     0.108767     5.935995  ...
# ...

# %%
for z in final_df.columns:
    print(z)
# Out:
# +/-
# 3P
# 3P%
# 3PA
# AST
# Age
# BLK
# DRB
# Date
# FG
# FG%
# FGA
# FT
# FT%
# FTA
# G
# GS
# GmSc
# MP
# ORB
# Opp
# PF
# PTS
# Rk
# STL
# TOV
# TRB
# Tm
# Unnamed: 5
# Unnamed: 7

# %%
#Drop columns that are irrelevant to analysis
#Dropping date as it will interrupt one hot encoding later on
new_df = final_df.drop(columns=['Rk','G','Age','Tm','Unnamed: 5','Opp','Unnamed: 7','GS','FG%','3P%','FT%','GmSc','+/-'])

# %%
new_df.head()
# Out:
#    3P  3PA  AST  BLK  DRB        Date  FG  FGA  FT  FTA     MP  ORB  PF  PTS  \
# 0   0    0    7    4    5  1984-10-26   5   16   6    7  40:00    1   2   16
# 1   0    0    5    1    2  1984-10-27   8   13   5    5  34:00    3   4   21
# 2   0    0    5    2    2  1984-10-29  13   24  11   13  34:00    2   4   37
# 3   0    0    5    1    2  1984-10-30   8   21   9    9  36:00    2   5   25
# 4   0    0    5    1    2  1984-11-01   7   15   3    4  33:00    3   4   17
#
#    STL  TOV  TRB
# 0    2    5    6
# 1    2    3    5
# 2    6    3    4
# 3    3    6    4
# 4    1    2    5

# %%
print('The shape of our data is:', new_df.shape)
# Out:
# The shape of our data is: (1072, 17)

# %%
# Import matplotlib for plotting and use magic command for Jupyter Notebooks
import matplotlib.pyplot as plt

# %matplotlib inline

# Set the style
plt.style.use('fivethirtyeight')

# %%
# Set up the plotting layout
fig, ((ax1), (ax2), (ax3), (ax4), (ax5)) = plt.subplots(nrows=5, ncols=1, figsize = (30,30))
fig.autofmt_xdate(rotation = 45)

# Field Goals 
ax1.bar(new_df['Date'], new_df['FG'])
ax1.set_xlabel('Date'); ax1.set_ylabel('Made'); ax1.set_title('Field Goals')

# Free Throws
ax2.bar(new_df['Date'], new_df['FT'])
ax2.set_xlabel('Date'); ax2.set_ylabel('Made'); ax2.set_title('Free Throw')

# Offensive Rebounds
ax3.bar(new_df['Date'], new_df['ORB'])
ax3.set_xlabel('Date'); ax3.set_ylabel('Made'); ax3.set_title('Offensive Rebounds')

# Turnovers
ax4.bar(new_df['Date'], new_df['TOV'])
ax4.set_xlabel('Date'); ax4.set_ylabel('Made'); ax4.set_title('Turnovers')

# Points
ax5.bar(new_df['Date'], new_df['PF'])
ax5.set_xlabel('Date'); ax5.set_ylabel('Made'); ax5.set_title('Personal Fouls')

plt.show
# Out:
# <function matplotlib.pyplot.show(*args, **kw)>
